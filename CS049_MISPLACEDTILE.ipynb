# %% [markdown]
# <a href="https://colab.research.google.com/github/aradhyTripathi2309/AI-5TH-SEM/blob/main/CS049_MISPLACEDTILE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def misplaced_tiles(state, goal):
    return sum(1 for i in range(3) for j in range(3) if state[i][j] != goal[i][j] and state[i][j] != 0)

def get_neighbors(state):
    neighbors = []
    blank = [(i, j) for i in range(3) for j in range(3) if state[i][j] == 0][0]
    possible_moves = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    x, y = blank

    for dx, dy in possible_moves:
        nx, ny = x + dx, y + dy
        if 0 <= nx < 3 and 0 <= ny < 3:
            new_state = [row[:] for row in state]
            new_state[x][y], new_state[nx][ny] = new_state[nx][ny], new_state[x][y]
            neighbors.append(new_state)

    return neighbors

def print_path(path):
    for state in path:
        for row in state:
            print(row)

        print('no. of misplaced tiles', misplaced_tiles(state, goal))
        print('PATH COST', len(path) - 1)
        print()

def astar_misplaced(start, goal):
    open_list = [(start, 0, [])]

    visited = set()

    while open_list:
        current, g, path = open_list.pop(0)


        path = path + [current]

        if current == goal:
            print("Solution Found:")
            print_path(path)


            return g

        for neighbor in get_neighbors(current):
            neighbor_tuple = tuple(map(tuple, neighbor))
            if neighbor_tuple not in visited:
                visited.add(neighbor_tuple)
                h = misplaced_tiles(neighbor, goal)
                open_list.append((neighbor, g + 1, path))

        open_list.sort(key=lambda x: x[1] + misplaced_tiles(x[0], goal))
    return -1

start = [[2, 8, 3], [1, 6, 4], [0, 7, 5]]
goal = [[1,2,3], [8,0,4], [7,6,5]]
astar_misplaced(start, goal)
# Out:
# Solution Found:
# [2, 8, 3]
# [1, 6, 4]
# [0, 7, 5]
# no. of misplaced tiles 5
# PATH COST 6
#
# [2, 8, 3]
# [1, 6, 4]
# [7, 0, 5]
# no. of misplaced tiles 4
# PATH COST 6
#
# [2, 8, 3]
# [1, 0, 4]
# [7, 6, 5]
# no. of misplaced tiles 3
# PATH COST 6
#
# [2, 0, 3]
# [1, 8, 4]
# [7, 6, 5]
# no. of misplaced tiles 3
# PATH COST 6
#
# [0, 2, 3]
# [1, 8, 4]
# [7, 6, 5]
# no. of misplaced tiles 2
# PATH COST 6
#
# [1, 2, 3]
# [0, 8, 4]
# [7, 6, 5]
# no. of misplaced tiles 1
# PATH COST 6
#
# [1, 2, 3]
# [8, 0, 4]
# [7, 6, 5]
# no. of misplaced tiles 0
# PATH COST 6
# 6

# %%
# Out:
# Current State:
# [[2, 8, 3], [0, 6, 4], [1, 7, 5]]
# g: 1, h: 5, f: 6
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 6, 4], [7, 0, 5]]
# g: 1, h: 4, f: 5
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 0, 4], [7, 6, 5]]
# g: 2, h: 3, f: 5
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 6, 4], [0, 7, 5]]
# g: 2, h: 5, f: 7
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 6, 4], [7, 5, 0]]
# g: 2, h: 5, f: 7
# ------------------------------
# Current State:
# [[2, 0, 3], [1, 8, 4], [7, 6, 5]]
# g: 3, h: 3, f: 6
# ------------------------------
# Current State:
# [[2, 8, 3], [0, 1, 4], [7, 6, 5]]
# g: 3, h: 3, f: 6
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 4, 0], [7, 6, 5]]
# g: 3, h: 4, f: 7
# ------------------------------
# Current State:
# [[0, 8, 3], [2, 6, 4], [1, 7, 5]]
# g: 2, h: 5, f: 7
# ------------------------------
# Current State:
# [[2, 8, 3], [6, 0, 4], [1, 7, 5]]
# g: 2, h: 5, f: 7
# ------------------------------
# Current State:
# [[0, 2, 3], [1, 8, 4], [7, 6, 5]]
# g: 4, h: 2, f: 6
# ------------------------------
# Current State:
# [[2, 3, 0], [1, 8, 4], [7, 6, 5]]
# g: 4, h: 4, f: 8
# ------------------------------
# Current State:
# [[0, 8, 3], [2, 1, 4], [7, 6, 5]]
# g: 4, h: 3, f: 7
# ------------------------------
# Current State:
# [[2, 8, 3], [7, 1, 4], [0, 6, 5]]
# g: 4, h: 4, f: 8
# ------------------------------
# Current State:
# [[1, 2, 3], [0, 8, 4], [7, 6, 5]]
# g: 5, h: 1, f: 6
# ------------------------------
# Current State:
# [[1, 2, 3], [7, 8, 4], [0, 6, 5]]
# g: 6, h: 2, f: 8
# ------------------------------
# Current State:
# [[1, 2, 3], [8, 0, 4], [7, 6, 5]]
# g: 6, h: 0, f: 6
# ------------------------------
# Solution Found:
# [2, 8, 3]
# [1, 6, 4]
# [0, 7, 5]
#
# [2, 8, 3]
# [1, 6, 4]
# [7, 0, 5]
#
# [2, 8, 3]
# [1, 0, 4]
# [7, 6, 5]
#
# [2, 0, 3]
# [1, 8, 4]
# [7, 6, 5]
#
# [0, 2, 3]
# [1, 8, 4]
# [7, 6, 5]
#
# [1, 2, 3]
# [0, 8, 4]
# [7, 6, 5]
#
# [1, 2, 3]
# [8, 0, 4]
# [7, 6, 5]
# 6

# %%
# Out:
# Current State:
# [[2, 8, 3], [0, 6, 4], [1, 7, 5]]
# g: 1, h: 5, f: 6
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 6, 4], [7, 0, 5]]
# g: 1, h: 4, f: 5
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 0, 4], [7, 6, 5]]
# g: 2, h: 3, f: 5
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 6, 4], [0, 7, 5]]
# g: 2, h: 5, f: 7
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 6, 4], [7, 5, 0]]
# g: 2, h: 5, f: 7
# ------------------------------
# Current State:
# [[2, 0, 3], [1, 8, 4], [7, 6, 5]]
# g: 3, h: 3, f: 6
# ------------------------------
# Current State:
# [[2, 8, 3], [0, 1, 4], [7, 6, 5]]
# g: 3, h: 3, f: 6
# ------------------------------
# Current State:
# [[2, 8, 3], [1, 4, 0], [7, 6, 5]]
# g: 3, h: 4, f: 7
# ------------------------------
# Current State:
# [[0, 8, 3], [2, 6, 4], [1, 7, 5]]
# g: 2, h: 5, f: 7
# ------------------------------
# Current State:
# [[2, 8, 3], [6, 0, 4], [1, 7, 5]]
# g: 2, h: 5, f: 7
# ------------------------------
# Current State:
# [[0, 2, 3], [1, 8, 4], [7, 6, 5]]
# g: 4, h: 2, f: 6
# ------------------------------
# Current State:
# [[2, 3, 0], [1, 8, 4], [7, 6, 5]]
# g: 4, h: 4, f: 8
# ------------------------------
# Current State:
# [[0, 8, 3], [2, 1, 4], [7, 6, 5]]
# g: 4, h: 3, f: 7
# ------------------------------
# Current State:
# [[2, 8, 3], [7, 1, 4], [0, 6, 5]]
# g: 4, h: 4, f: 8
# ------------------------------
# Current State:
# [[1, 2, 3], [0, 8, 4], [7, 6, 5]]
# g: 5, h: 1, f: 6
# ------------------------------
# Current State:
# [[1, 2, 3], [7, 8, 4], [0, 6, 5]]
# g: 6, h: 2, f: 8
# ------------------------------
# Current State:
# [[1, 2, 3], [8, 0, 4], [7, 6, 5]]
# g: 6, h: 0, f: 6
# ------------------------------
# Solution Found:
# Step 0:
# [[2, 8, 3], [1, 6, 4], [0, 7, 5]]
# g: 0, h: 5
# ------------------------------
# Step 1:
# [[2, 8, 3], [1, 6, 4], [7, 0, 5]]
# g: 1, h: 4
# ------------------------------
# Step 2:
# [[2, 8, 3], [1, 0, 4], [7, 6, 5]]
# g: 2, h: 3
# ------------------------------
# Step 3:
# [[2, 0, 3], [1, 8, 4], [7, 6, 5]]
# g: 3, h: 3
# ------------------------------
# Step 4:
# [[0, 2, 3], [1, 8, 4], [7, 6, 5]]
# g: 4, h: 2
# ------------------------------
# Step 5:
# [[1, 2, 3], [0, 8, 4], [7, 6, 5]]
# g: 5, h: 1
# ------------------------------
# Step 6:
# [[1, 2, 3], [8, 0, 4], [7, 6, 5]]
# g: 6, h: 0
# ------------------------------
# 6
