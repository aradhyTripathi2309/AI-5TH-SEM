# %% [markdown]
# <a href="https://colab.research.google.com/github/aradhyTripathi2309/AI-5TH-SEM/blob/main/8puzzle_ids.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ITERATIVE DEEPENING SEARCH


import copy
def find_blank_position(state):
    for i in range(len(state)):
        for j in range(len(state[i])):
            if state[i][j] == 0:
                return i, j


def get_possible_moves(state):
    moves = []
    row, col = find_blank_position(state)
    if row > 0:  # Move up
        moves.append((row - 1, col))
    if row < 2:  # Move down
        moves.append((row + 1, col))
    if col > 0:  # Move left
        moves.append((row, col - 1))
    if col < 2:  # Move right
        moves.append((row, col + 1))
    return moves

def move_tile(state, new_row, new_col):
    row, col = find_blank_position(state)
    new_state = copy.deepcopy(state)
    new_state[row][col], new_state[new_row][new_col] = new_state[new_row][new_col], new_state[row][col]
    return new_state


def dfs_with_limit(state, goal, depth, visited):
    if state == goal:
        return True
    if depth == 0:
        return False

    visited.append(state)
    possible_moves = get_possible_moves(state)

    for move in possible_moves:
        new_state = move_tile(state, move[0], move[1])
        if new_state not in visited:
            if dfs_with_limit(new_state, goal, depth - 1, visited):
                return True
    visited.pop()
    return False


def ids(start, goal):
    depth = 0
    while True:
        visited = []
        if dfs_with_limit(start, goal, depth, visited):
            return visited
        depth += 1


def display_state(state):
    for row in state:
        print(row)
    print()


start_state = [
    [1, 2, 3],
    [4, 0, 6],
    [7, 5, 8]
]

goal_state = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 0]
]

if __name__ == '__main__':
    print("Initial State:")
    display_state(start_state)

    print("Goal State:")
    display_state(goal_state)

    result = ids(start_state, goal_state)
    if result:
        print("Solution Found! Steps:")
        for step in result:
            display_state(step)
    else:
        print("No solution exists!")
-_
